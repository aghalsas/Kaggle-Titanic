# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegressionCV
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
from scipy.stats import skew
from scipy.special import boxcox1p

# %%
## Inputting data
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

PassengerId = test["PassengerId"]

train.drop(['PassengerId'],axis=1,inplace=True)
test.drop(['PassengerId'],axis=1,inplace=True)

all_data = pd.concat([train.drop('Survived',axis=1),test])


## Converting categorical variables to numerical
all_data = all_data.replace({'male': 0, 'female': 1})
all_data['Family'] = all_data['SibSp']+all_data['Parch']
#all_data['Child'] = all_data['Age'].loc(all_data['Age']<16)
all_data['Child'] = all_data['Age']<16
numeric_feats = all_data.dtypes[all_data.dtypes != "object"].index
all_data = all_data[numeric_feats]
all_data.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Family  Child
# 0       3    0  22.0      1      0   7.2500       1  False
# 1       1    1  38.0      1      0  71.2833       1  False
# 2       3    1  26.0      0      0   7.9250       0  False
# 3       1    1  35.0      1      0  53.1000       1  False
# 4       3    0  35.0      0      0   8.0500       0  False

# %%
## Filling missing variables with the median (dumb replacement)
def medianreplace(data):
    k = (data.isna().sum()!=0).sum()
    idx = data.isna().sum().nlargest(k).index[::-1]
    for i in idx:
        data[i] = data[i].fillna(data[i].median())
    
    return data

# %%
## Smarter replace using groupby
def groupbymedianreplace(data,feat):
    k = (data.isna().sum()!=0).sum()
    idx = data.isna().sum().nlargest(k).index[::-1]
    for i in idx:
        data[i].fillna(data.groupby(feat)[i].transform("median"), inplace=True)
    
    return data

# %%
#all_data = medianreplace(all_data)
all_data = groupbymedianreplace(all_data,['Sex','Pclass'])
#all_data['Age'] = np.log1p(all_data['Age'])
all_data['Age'] = (all_data['Age']-all_data['Age'].mean(axis=0))/all_data['Age'].std(axis=0)
all_data['Fare'] = np.log1p(all_data['Fare'])
all_data['Fare'] = (all_data['Fare']-all_data['Fare'].mean(axis=0))/all_data['Fare'].std(axis=0)
train = pd.concat([all_data.iloc[0:train.shape[0]],train['Survived']],axis=1)
test = all_data.iloc[train.shape[0]:]

# %%
corrmat = np.abs(train.corr())
k = train.shape[1]
cols = corrmat.nlargest(k, 'Survived')['Survived'].index
print(cols,corrmat)
# Out:
# Index(['Survived', 'Sex', 'Pclass', 'Fare', 'Child', 'Parch', 'SibSp', 'Age',
#        'Family'],
#       dtype='object')             Pclass       Sex       Age     SibSp     Parch      Fare  \
# Pclass    1.000000  0.131900  0.416872  0.083081  0.018443  0.536338
# Sex       0.131900  1.000000  0.099553  0.114631  0.245489  0.146923
# Age       0.416872  0.099553  1.000000  0.105891  0.001652  0.257809
# SibSp     0.083081  0.114631  0.105891  1.000000  0.414838  0.247550
# Parch     0.018443  0.245489  0.001652  0.414838  1.000000  0.233408
# Fare      0.536338  0.146923  0.257809  0.247550  0.233408  1.000000
# Family    0.065997  0.200988  0.073198  0.890712  0.783111  0.291295
# Child     0.121920  0.111141  0.097685  0.352437  0.351481  0.060086
# Survived  0.338481  0.543351  0.032146  0.035322  0.081629  0.239116
#
#             Family     Child  Survived
# Pclass    0.065997  0.121920  0.338481
# Sex       0.200988  0.111141  0.543351
# Age       0.073198  0.097685  0.032146
# SibSp     0.890712  0.352437  0.035322
# Parch     0.783111  0.351481  0.081629
# Fare      0.291295  0.060086  0.239116
# Family    1.000000  0.416472  0.016639
# Child     0.416472  1.000000  0.136107
# Survived  0.016639  0.136107  1.000000

# %%
for n in range(2,9):
    x = train[cols[1:n]].copy()
#    x.drop('Survived', axis=1,inplace = True)
    y = train['Survived']

    model = LogisticRegressionCV(cv = 10, fit_intercept= True)
    model.fit(x,y)
    print(model.score(x,y))
print(n)
# Out:
# 0.7867564534231201
# 0.7867564534231201
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-785e3a921d30> in <module>
#       5
#       6     model = LogisticRegressionCV(cv = 10, fit_intercept= True)
# ----> 7     model.fit(x,y)
#       8     print(model.score(x,y))
#       9 print(n)
#
# ~\Anaconda3_1\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1613
#    1614         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
# -> 1615                          order="C")
#    1616         check_classification_targets(y)
#    1617
#
# ~\Anaconda3_1\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3_1\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# ~\Anaconda3_1\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
model.coef_
# Out:
# array([[ 2.73169566, -1.10609526,  0.17280962,  1.22516945, -0.18441138,
#         -0.39153879, -0.45667521]])

# %%
test_copy = test[cols[1:n]].copy()
predictions = model.predict(test_copy)

# %%
submission = pd.DataFrame({"PassengerId":PassengerId, "Survived":predictions})
submission.to_csv("submission.csv", index=False)

# %%
all_data.groupby(['Sex','Pclass'])['Age'].mean()

# %%
all_data.loc(all_data['Age']<16)

# %%
all_data
# Out:
#      Pclass  Sex       Age  SibSp  Parch      Fare  Family  Child
# 0         3    0 -0.549345      1      0 -0.502981       1  False
# 1         1    1  0.661100      1      0  0.734529       1  False
# 2         3    1 -0.246734      0      0 -0.489936       0  False
# 3         1    1  0.434142      1      0  0.383118       1  False
# 4         3    0  0.434142      0      0 -0.487520       0  False
# 5         3    0 -0.322387      0      0 -0.479629       0  False
# 6         1    0  1.871545      0      0  0.359202       0  False
# 7         3    0 -2.062402      3      1 -0.235799       4   True
# 8         3    1 -0.171081      0      2 -0.427932       2  False
# 9         2    1 -1.154568      1      0 -0.061945       1   True
# 10        3    1 -1.911096      1      1 -0.320350       2   True
# 11        1    1  2.174157      0      0 -0.129988       0  False
# 12        3    0 -0.700651      0      0 -0.487520       0  False
# 13        3    0  0.736753      1      5 -0.038673       6  False
# 14        3    1 -1.154568      0      0 -0.491304       0   True
# 15        2    1  1.947198      0      0 -0.333878       0  False
# 16        3    0 -2.062402      4      1 -0.080224       5   True
# 17        2    0  0.018051      0      0 -0.391856       0  False
# 18        3    1  0.131530      1      0 -0.295226       1  False
# 19        3    1 -0.549345      0      0 -0.503464       0  False
# 20        2    0  0.434142      0      0 -0.140618       0  False
# 21        2    0  0.358489      0      0 -0.391856       0  False
# 22        3    1 -1.078915      0      0 -0.487922       0   True
# 23        1    0 -0.095428      0      0  0.042980       0  False
# 24        3    1 -1.608485      3      1 -0.235799       4   True
# 25        3    1  0.661100      1      5 -0.036499       6  False
# 26        3    0 -0.322387      0      0 -0.503464       0  False
# 27        1    0 -0.776304      3      2  4.439655       5  False
# 28        3    1 -0.549345      0      0 -0.490821       0  False
# 29        3    0 -0.322387      0      0 -0.490500       0  False
# ..      ...  ...       ...    ...    ...       ...     ...    ...
# 388       3    0 -0.624998      0      0 -0.493318       0  False
# 389       3    0 -1.759791      3      1 -0.235799       4   True
# 390       1    0 -0.473693      0      0  1.163890       0  False
# 391       1    1  1.644587      0      1  0.118351       1  False
# 392       3    0 -1.230221      0      2 -0.251743       2   True
# 393       2    0  1.341976      0      0 -0.440171       0  False
# 394       3    0 -0.019776      3      1 -0.217439       4  False
# 395       1    1 -0.851957      1      0  0.516468       1  False
# 396       3    0 -0.398040      0      0 -0.502981       0  False
# 397       1    1  1.417628      1      1  0.887528       2  False
# 398       3    0 -0.549345      0      0 -0.492835       0  False
# 399       3    0  0.131530      0      0 -0.493641       0  False
# 400       1    1  0.055877      0      0  2.543126       0  False
# 401       2    0  0.661100      1      0 -0.237248       1  False
# 402       1    1 -0.549345      0      1  0.504872       1  False
# 403       1    0 -0.927610      0      0  0.267162       0  False
# 404       1    0  1.039364      1      0 -0.107362       1  False
# 405       2    0 -0.700651      0      0 -0.375188       0  False
# 406       2    0 -0.473693      1      0 -0.440171       1  False
# 407       1    0  1.568934      1      1  3.444364       2  False
# 408       3    1 -0.549345      0      0 -0.493882       0  False
# 409       3    1 -1.986749      1      1 -0.376879       2   True
# 410       3    1 -0.549345      0      0 -0.493318       0  False
# 411       1    1  0.585447      1      0  1.096249       1  False
# 412       3    1 -0.095428      0      0 -0.492835       0  False
# 413       3    0 -0.322387      0      0 -0.487520       0  False
# 414       1    1  0.736753      0      0  1.461511       0  False
# 415       3    0  0.698926      0      0 -0.502981       0  False
# 416       3    0 -0.322387      0      0 -0.487520       0  False
# 417       3    0 -0.322387      1      1 -0.210997       2  False
#
# [1309 rows x 8 columns]

# %%
skew(all_data['Fare'])
# Out:
# 4.364196021412905
